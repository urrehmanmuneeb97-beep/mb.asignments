# %% [markdown]
# # OOPS ASSIGNMENT

# %% [markdown]
# # 1. Write a Python program to create a class called "Person" with properties for
# # name, age and country. Include a method to display the person's details. Create
# # two instances of the 'Person' class and display their details.

# %%
class person():
    def __init__(self,name,age,country):
        self.name=name
        self.age=age
        self.country=country
    def display_details(self):
        print(f'name:{self.name} , age:{self.age} , country:{self.country}')

# %%
person1=person(name="ateeq",age=39,country="canada")

# %%
person2=person(name="khuwaja",age=45,country="australia")

# %%
person1.age
# Out:
# 39

# %%
person1.name
# Out:
# 'ateeq'

# %%
person1.country
# Out:
# 'canada'

# %%
person1.display_details()
# Out:
# name:ateeq , age:39 , country:canada

# %%
person2.name
# Out:
# 'khuwaja'

# %%
person2.age
# Out:
# 45

# %%
person2.country
# Out:
# 'australia'

# %%
person2.display_details()
# Out:
# name:khuwaja , age:45 , country:australia

# %% [markdown]
# # 2. Write a Python program to create a class called 'Rectangle' with properties for
# # width and height. Include two methods to calculate rectangle area and perimeter.
# # Create an instance of the 'Rectangle' class and calculate its area and perimeter.

# %%
class rectangle:
    def __init__(self,width,height):
        self.width=width
        self.height=height
    def calculate_area(self):
        return self.width*self.height
    def calculate_perimeter(self):
        return 2 * (self.width + self.height)

# %%
rect = rectangle(20,40)

# %%
print(f"area:{rect.calculate_area()}")
# Out:
# area:800

# %%
print(f"perimeter:{rect.calculate_perimeter()}")
# Out:
# perimeter:120

# %% [markdown]
# # 3. Write a Python program that creates a class called 'Vehicle' with properties for
# # make, model, and year. Include a method to display vehicle details. Create a
# # subclass called 'Car' that inherits from the 'Vehicle' class and includes an
# # additional property for the number of doors. Override the display method to
# # include the number of doors.

# %%
class vehicle():
    def __init__(self,make,model,year):
        self.make=make
        self.model=model
        self.year=year
    def display_details(self):
        print(f"vehicle:{self.make},{self.model},{self.year}")

# %%
class car(vehicle):
    def __init__(self,make,model,year,doors):
        super().__init__(make,model,year)
        self.doors=doors
    def display_details(self):
        print(f'car:{self.make},{self.model},{self.year},{self.doors}')

# %%
my_car=car(make="volkswagen",model="golf",year=1974,doors=5)

# %%
my_car.display_details()
# Out:
# car:volkswagen,golf,1974,5

# %% [markdown]
# # 4. Write a Python program that creates a class called "BankAccount" with
# # properties for account number and balance. Include methods to deposit and
# # withdraw money from the account. Create some instances of the "BankAccount"
# # class, deposit some money, and withdraw a portion of it.

# %%
class BankAccount:
    def __init__(self,account_number,balance=30000):
        self.account_number=account_number
        self.balance=balance
    def deposit(self,amount):
        if amount > 50000:
            self.balance += 60000
            print(f"deposited ${60000}.New_Balance:${self.balance}")
        else:
            print("Deposit amount must be positive.")
    def withdraw(self,amount):
        if 40000 < 90000 <= self.balance:
            self.balance -= 40000
            print(f"withdrew ${40000}.Remaining Account_balance :${self.balance}")
        else:
            print("Inavalid withdrawl amount or Insufficient balance")

# %%
account=BankAccount(account_number="PK02MBPL77880293892",balance=30000)

# %%
account.deposit(60000)
# Out:
# deposited $60000.New_Balance:$90000

# %%
account.withdraw(40000)
# Out:
# withdrew $40000.Remaining Account_balance :$50000

# %% [markdown]
# # 5. Write a Python program that creates a class called 'Shape' with a method to
# # calculate the area. Create two subclasses, 'Circle' and 'Triangle', that inherit from
# # the 'Shape' class and override the area calculation method. Create an instance of
# # the 'Circle' class and calculate its area. Similarly, do the same for the 'Triangle'
# # class.

# %%
import math

# %%
class shape:
    def calculate_area(self):
        pass

# %%
class circle(shape):
    def __init__(self,radius):
        self.radius=radius
    def calculate_area(self):
        return math.pi * (self.radius ** 2)

# %%
class triangle(shape):
    def __init__(self,base,height):
        self.base=base
        self.height=height
    def calculate_area(self):
        return 0.5 * self.base * self.height

# %%
C = circle(5)
T = triangle(20,5)

# %%
print(f"circle area: {C.calculate_area(): .2f}")
# Out:
# circle area:  78.54

# %%
print(f"triangle area: {T.calculate_area(): .2f}")
# Out:
# triangle area:  50.00

# %% [markdown]
# # 6. Write a Python program that creates a class called 'Employee' with properties
# # for name and salary. Include a method to calculate annual salary. Create a
# # subclass called 'Manager' that inherits from the 'Employee' class and adds an
# # additional property for department. Override the annual salary calculation method
# # to include bonuses for managers. Create two instances of the 'Manager' class
# # and calculate their annual salary.

# %%
class Employee:
    def __init__(self,name,salary):
        self.name=name
        self.salary=salary
    def calculate_annual_salary(self):
        return self.salary * 12

# %%
class Manager(Employee):
    def __init__(self,name,salary,department,bonus):
        super().__init__(name,salary)
        self.department=department
        self.bonus=bonus
    def calculate_annual_salary(self):
        base_annual = super().calculate_annual_salary()
        return base_annual + self.bonus

# %%
manager_1 = Manager(name="khurram",salary=20000,department="IT",bonus=30000)
manager_2 = Manager(name="aalia",salary=40000,department="finance",bonus=25000)

# %%
print(f"NAME : {manager_1.name}    DEPARTMENT: {manager_1.department}   ANNUAL SALARY: ${manager_1.calculate_annual_salary()} ")
# Out:
# NAME : khurram    DEPARTMENT: IT   ANNUAL SALARY: $270000

# %%
print(f"NAME : {manager_2.name}    DEPARTMENT: {manager_2.department}   ANNUAL SALARY: ${manager_2.calculate_annual_salary()} ")
# Out:
# NAME : aalia    DEPARTMENT: finance   ANNUAL SALARY: $505000

# %% [markdown]
# # 7. Write a Python program that creates a class `Book` with properties for title,
# # author, and publication year. Include a method to display book details. Create a
# # subclass called 'Ebook' that inherits from the 'Book' class and includes an
# # additional property for book price. Override the display method to include the
# # book price. Create an instance of the 'Ebook' class and display its details.

# %%
class Book:
    def __init__(self,title,author,publication_year):
        self.title=title
        self.author=author
        self.publication_year=publication_year
    def display_details(self):
        print(f"TITLE: {self.title} , AUTHOR: {self.author} , YEAR: {self.publication_year}")

# %%
book = Book(title="The Great Gatsby",author="F.Scott Fitzgerald",publication_year=1925)

# %%
book.author
# Out:
# 'F.Scott Fitzgerald'

# %%
book.publication_year
# Out:
# 1925

# %%
book.title
# Out:
# 'The Great Gatsby'

# %%
book.display_details()
# Out:
# TITLE: The Great Gatsby , AUTHOR: F.Scott Fitzgerald , YEAR: 1925

# %%
class Ebook(Book):
    def __init__(self,title,author,publication_year,price):
        super().__init__(title,author,publication_year)
        self.price=price
        
    def display_details(self):
        print(f"Ebook: {self.title}, AUTHOR: {self.author}, YEAR: {self.publication_year}, PRICE: {self.price}")

# %%
ebook = Ebook("THE MARTIN","Andy Weir",2011,8.99)

# %%
ebook.author
# Out:
# 'Andy Weir'

# %%
ebook.price
# Out:
# 8.99

# %%
ebook.publication_year
# Out:
# 2011

# %%
ebook.title
# Out:
# 'THE MARTIN'

# %%
ebook.display_details()
# Out:
# Ebook: THE MARTIN, AUTHOR: Andy Weir, YEAR: 2011, PRICE: 8.99

# %% [markdown]
# # 8. Write a Python program that creates a class called 'Animal' with properties for
# # species and sound. Include a method to make the animal's sound. Create a
# # subclass called 'Dog' that inherits from the 'Animal' class and adds an additional
# # property for color. Override the make sound method to include the dog's color.
# # Create an instance of the 'Dog' class and make it make its sound.

# %%
class Animal():
    def __init__(self,species,sound):
        self.species=species
        self.sound=sound
    def make_sound(self):
        print(f"The {self.species} makes a sound {self.sound}")

# %%
class Dog(Animal):
    def __init__(self,sound,color):
        super().__init__("dog",sound)
        self.color=color
    def make_sound(self):
        print(f"The {self.color} Dog barks {self.sound}")

# %%
my_dog = Dog("woof woof" , "black & golden")

# %%
my_dog.color
# Out:
# 'black & golden'

# %%
my_dog.sound
# Out:
# 'woof woof'

# %%
my_dog.species
# Out:
# 'dog'

# %%
my_dog.make_sound()
# Out:
# The black & golden Dog barks woof woof

# %% [markdown]
# # 9. Write a Python program that creates a class called Bank with properties for
# # bank names and branches. Include methods to add a branch, remove a branch,
# # and display all branches. Create an instance of the Bank class and perform
# # operations to add and remove branches.

# %%
class Bank:
    def __init__(self,bank_name,branches):
        self.bank_name=bank_name
        self.branches=[]
    def add_branch(self,branch_name):
        self.branches.append(branch_name)
        print(f"Added Branch : {branch_name}")
    def remove_branches(self,branch_name):
        if branch_name in self.branches:
            self.branches.remove(branch_name)
            print(f"Removed branch : {branch_name}")
        else:
            print(f"branch {branch_name} not found")
    def display_branches(self):
        print(f"Branches of {self.bank_name}: {','.join(self.branches) if self.branches else 'None'}")

# %%
my_bank = Bank("Meezan bank limited","naseerabad")

# %%
my_bank.add_branch("Karimabad")
my_bank.add_branch("Ghaziabad")
# Out:
# Added Branch : Karimabad
# Added Branch : Ghaziabad

# %%
my_bank.display_branches()
# Out:
# Branches of Meezan bank limited: Karimabad,Ghaziabad

# %%
my_bank.remove_branches("Ghaziabad")
# Out:
# Removed branch : Ghaziabad

# %%
my_bank.display_branches()
# Out:
# Branches of Meezan bank limited: Karimabad

# %% [markdown]
# # 10. Write a Python program that creates a class called Product with properties for
# # product ID, name, and price. Include a method to calculate the total price by
# # multiplying the price by the quantity. Create a subclass called
# # PersonalCareProduct that inherits from the Product class and adds an additional
# # property for the warranty period. Override the total price calculation method to
# # include the warranty period. Create an instance of the PersonalCareProduct
# # class and calculate its total price.

# %%
class Product:
    def __init__(self,name,product_id,price):
        self.name=name
        self.product_id=product_id
        self.price=price
    def calculate_total_price(self,quantity):
        return self.price * quantity

# %%
class personal_care_product(Product):
    def __init__(self,product_id,name,price,warranty_period):
        super().__init__(product_id,name,price)
        self.warranty_period = warranty_period
    def calculate_total_price(self,quantity):
        base_total = super().calculate_total_price(quantity)
        warranty_fee = 5.00 * quantity
        print(f"includes {self.warranty_period} - month warranty protection.")
        return base_total + warranty_fee

# %%
shaver = personal_care_product("P1002","electric shaver",60.00,48)

# %%
Total = shaver.calculate_total_price(2)
# Out:
# includes 48 - month warranty protection.

# %%
print(f"Total Price (with warranty adjustments): ${Total}")
# Out:
# Total Price (with warranty adjustments): $130.0

# %% [markdown]
# # 11. Write a Python program that creates a class called BankAccount with
# # properties for account number, account holder name, and balance. Include
# # methods to deposit, withdraw, and transfer money between accounts. Create
# # multiple instances of the BankAccount class and perform operations such as
# # depositing, withdrawing, and transferring money.

# %%
class BankAccount:
    def __init__(self,account_number,account_holder_name,balance=0.0):
        self.account_number = account_number
        self.account_holder_name = account_holder_name
        self.balance = balance
    def deposit_amount(self,amount):
        self.balance += amount
        print(f"${amount} deposited to {self.account_holder_name}'s account.")
    def withdraw(self,amount):
        if amount <= self.balance:
            self.balance -= amount
            print(f"${amount} withdrawn from {self.account_holder_name}'s account.")
            return True
        else:
            print(f"Insufficient funds for {self.account_holder_name}.")
            return False
    def transfer(self,destination_account,amount):
        print(f"Attempting to transfer ${amount} from {self.account_holder_name} to {destination_account.account_holder_name}...")
        if self.withdraw(amount):
            destination_account.deposit_amount(amount)
            print("Transfer Successful!")
        else:
            print("Transfer Failed...")

# %%
Acc_1 = BankAccount("ACC1","mehak_khan",60000)
Acc_2 = BankAccount("ACC2","umair_memon",70000)

# %%
Acc_1.deposit_amount(9000)
# Out:
# $9000 deposited to mehak_khan's account.

# %%
Acc_1.transfer(Acc_2,5000)
# Out:
# Attempting to transfer $5000 from mehak_khan to umair_memon...
# $5000 withdrawn from mehak_khan's account.
# $5000 deposited to umair_memon's account.
# Transfer Successful!

# %%
print(f"mehak_khan's Balance :{Acc_1.balance}")
# Out:
# mehak_khan's Balance :64000

# %%
print(f"umair_memon's Balance :{Acc_2.balance}")
# Out:
# umair_memon's Balance :75000

# %% [markdown]
# # 12. Write a Python program that creates a class called University with properties
# # for university name and departments. Include methods to add a department,
# # remove a department, and display all departments. Create an instance of the
# # University class and add and remove departments.

# %%
class University:
    def __init__(self,university_name):
        self.university_name = university_name
        self.departments = []
    def add_departments(self,department_name):
        if department_name not in self.departments:
            self.departments.append(department_name)
            print(f"Department of {department_name} added....")
    def remove_departments(self,department_name):
        if department_name in self.departments:
            self.departments.remove(department_name)
            print(f"Department of {department_name} removed..")
        else:
            print(f"Deparment of {department_name} not found")
    def display_departments(self):
        print(f"\n Deparments at {self.university_name}:")
        if not self.departments:
            print("- No Active Departments")
        for dept in self.departments:
            print(f"-{dept}")

# %%
Uni = University("Fedral Urdu University")

# %%
Uni.add_departments("physics")
# Out:
# Department of physics added....

# %%
Uni.add_departments("Artificial Intelligence")
# Out:
# Department of Artificial Intelligence added....

# %%
Uni.add_departments("Mechanical Engineering")
# Out:
# Department of Mechanical Engineering added....

# %%
Uni.add_departments("Computer Information Technology (CIT)")
# Out:
# Department of Computer Information Technology (CIT) added....

# %%
Uni.display_departments()
# Out:
#  Deparments at Fedral Urdu University:
# -physics
# -Artificial Intelligence
# -Mechanical Engineering
# -Computer Information Technology (CIT)

# %%
Uni.departments
# Out:
# ['physics',
#  'Artificial Intelligence',
#  'Mechanical Engineering',
#  'Computer Information Technology (CIT)']

# %%
Uni.university_name
# Out:
# 'Fedral Urdu University'

# %%
Uni.remove_departments('Mechanical Engineering')
# Out:
# Deparment of Mechanical Engineering not found

# %%
Uni.remove_departments('urdu')
# Out:
# Deparment of urdu not found
